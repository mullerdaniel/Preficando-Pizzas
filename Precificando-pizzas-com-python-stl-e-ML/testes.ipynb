# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\daniel_muller150\Documents\TODAS_AS_LINGUAGENS\Python\Precificando-pizzas-com-python-stl-e-ML\pizzas.csv')

# %%
print(df.head())
# Out:
#    diametro  preco
# 0        20     50
# 1        22     55
# 2        24     60
# 3        26     65
# 4        28     70
